# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings

from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold, cross_val_score, cross_validate
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/cleaned_f1_data.csv')

# %% [markdown]
# Data Preparation

# %%
def preprocess_stints(df):
    # Drop outdated columns (ignore if missing)
    df.drop(columns=['RaceName', 'TyresChange', 'LapStint', 'StintNum', 'StintID'], inplace=True, errors='ignore')

    # Convert Time column to timedelta
    df['Time'] = pd.to_timedelta(df['Time'], errors='coerce')

    # Detect tire compound changes
    df['TireChange'] = df['Compound'] != df.groupby(['Driver', 'RaceID'])['Compound'].shift(1)
    df['TireChange'] = df['TireChange'].fillna(False)
    df['IsPitLap'] = df['PitInTime'].notnull()
    df['NumPitStops'] = (
        df.groupby(['Year', 'RaceName', 'Driver'])['IsPitLap'].cumsum()
    )

    df['IsRedFlagTireSwap'] = df['TiresChange'] & ~df['IsPitLap']
    # Assign stint numbers
    df['StintNum'] = df.groupby(['Driver', 'RaceID'])['TireChange'].cumsum().astype(int)  # start at 
    # Lap number within the stint
    df['LapStint'] = df.groupby(['Driver', 'RaceID', 'StintNum']).cumcount() + 1

    # Stint start time = first lap time in that stint
    df['StintStartTime'] = df.groupby(['Driver', 'StintNum'])['Time'].transform('first')

    # Time on tire = time since stint start
    df['TimeOnTireSeconds'] = (df['Time'] - df['StintStartTime']).dt.total_seconds()

    return df

# %%
df = preprocess_stints(df)

# %%
df[['Driver', 'RaceID', 'LapNumber', 'Time', 'StintStartTime', 'TimeOnTireSeconds', 'Compound', 'LapStint', 'StintNum', 'LapTime', 'Position']].head(50)
# Out:
#    Driver                     RaceID  LapNumber                   Time  \
# 0     NOR  2024_Singapore_Grand_Prix        1.0 0 days 00:58:41.675000
# 1     VER  2024_Singapore_Grand_Prix        1.0 0 days 00:58:42.664000
# 2     HAM  2024_Singapore_Grand_Prix        1.0 0 days 00:58:43.953000
# 3     RUS  2024_Singapore_Grand_Prix        1.0 0 days 00:58:45.073000
# 4     PIA  2024_Singapore_Grand_Prix        1.0 0 days 00:58:46.519000
# 5     HUL  2024_Singapore_Grand_Prix        1.0 0 days 00:58:46.974000
# 6     ALO  2024_Singapore_Grand_Prix        1.0 0 days 00:58:47.635000
# 7     LEC  2024_Singapore_Grand_Prix        1.0 0 days 00:58:48.341000
# 8     COL  2024_Singapore_Grand_Prix        1.0 0 days 00:58:48.947000
# 9     PER  2024_Singapore_Grand_Prix        1.0 0 days 00:58:49.401000
# 10    TSU  2024_Singapore_Grand_Prix        1.0 0 days 00:58:50.150000
# 11    SAI  2024_Singapore_Grand_Prix        1.0 0 days 00:58:50.752000
# 12    OCO  2024_Singapore_Grand_Prix        1.0 0 days 00:58:51.178000
# 13    MAG  2024_Singapore_Grand_Prix        1.0 0 days 00:58:51.660000
# 14    ALB  2024_Singapore_Grand_Prix        1.0 0 days 00:58:52.022000
# 15    RIC  2024_Singapore_Grand_Prix        1.0 0 days 00:58:52.570000
# 16    GAS  2024_Singapore_Grand_Prix        1.0 0 days 00:58:53.232000
# 17    STR  2024_Singapore_Grand_Prix        1.0 0 days 00:58:53.860000
# 18    BOT  2024_Singapore_Grand_Prix        1.0 0 days 00:58:54.612000
# 19    ZHO  2024_Singapore_Grand_Prix        1.0 0 days 00:58:55.073000
# 20    NOR  2024_Singapore_Grand_Prix        2.0 0 days 01:00:20.155000
# 21    VER  2024_Singapore_Grand_Prix        2.0 0 days 01:00:21.454000
# 22    HAM  2024_Singapore_Grand_Prix        2.0 0 days 01:00:22.806000
# 23    RUS  2024_Singapore_Grand_Prix        2.0 0 days 01:00:23.562000
# 24    PIA  2024_Singapore_Grand_Prix        2.0 0 days 01:00:25.458000
# 25    HUL  2024_Singapore_Grand_Prix        2.0 0 days 01:00:26.423000
# 26    ALO  2024_Singapore_Grand_Prix        2.0 0 days 01:00:27.219000
# 27    LEC  2024_Singapore_Grand_Prix        2.0 0 days 01:00:28.116000
# 28    COL  2024_Singapore_Grand_Prix        2.0 0 days 01:00:28.837000
# 29    PER  2024_Singapore_Grand_Prix        2.0 0 days 01:00:29.297000
# 30    TSU  2024_Singapore_Grand_Prix        2.0 0 days 01:00:30.144000
# 31    SAI  2024_Singapore_Grand_Prix        2.0 0 days 01:00:30.969000
# 32    OCO  2024_Singapore_Grand_Prix        2.0 0 days 01:00:31.583000
# 33    MAG  2024_Singapore_Grand_Prix        2.0 0 days 01:00:32.046000
# 34    ALB  2024_Singapore_Grand_Prix        2.0 0 days 01:00:32.772000
# 35    RIC  2024_Singapore_Grand_Prix        2.0 0 days 01:00:33.517000
# 36    GAS  2024_Singapore_Grand_Prix        2.0 0 days 01:00:34.180000
# 37    STR  2024_Singapore_Grand_Prix        2.0 0 days 01:00:35.044000
# 38    BOT  2024_Singapore_Grand_Prix        2.0 0 days 01:00:35.777000
# 39    ZHO  2024_Singapore_Grand_Prix        2.0 0 days 01:00:36.668000
# 40    NOR  2024_Singapore_Grand_Prix        3.0 0 days 01:01:58.561000
# 41    VER  2024_Singapore_Grand_Prix        3.0 0 days 01:02:00.371000
# 42    HAM  2024_Singapore_Grand_Prix        3.0 0 days 01:02:02.060000
# 43    RUS  2024_Singapore_Grand_Prix        3.0 0 days 01:02:03.274000
# 44    PIA  2024_Singapore_Grand_Prix        3.0 0 days 01:02:04.808000
# 45    HUL  2024_Singapore_Grand_Prix        3.0 0 days 01:02:05.645000
# 46    ALO  2024_Singapore_Grand_Prix        3.0 0 days 01:02:06.505000
# 47    LEC  2024_Singapore_Grand_Prix        3.0 0 days 01:02:07.256000
# 48    COL  2024_Singapore_Grand_Prix        3.0 0 days 01:02:08.208000
# 49    PER  2024_Singapore_Grand_Prix        3.0 0 days 01:02:08.926000
#
#            StintStartTime  TimeOnTireSeconds Compound  LapStint  StintNum  \
# 0  0 days 00:58:41.675000              0.000   MEDIUM         1         1
# 1  0 days 00:58:42.664000              0.000   MEDIUM         1         1
# 2  0 days 00:58:43.953000              0.000     SOFT         1         1
# 3  0 days 00:58:45.073000              0.000   MEDIUM         1         1
# 4  0 days 00:58:46.519000              0.000   MEDIUM         1         1
# 5  0 days 00:58:46.974000              0.000   MEDIUM         1         1
# 6  0 days 00:58:47.635000              0.000   MEDIUM         1         1
# 7  0 days 00:58:48.341000              0.000   MEDIUM         1         1
# 8  0 days 00:58:48.947000              0.000   MEDIUM         1         1
# 9  0 days 00:58:49.401000              0.000   MEDIUM         1         1
# 10 0 days 00:58:50.150000              0.000   MEDIUM         1         1
# 11 0 days 00:58:50.752000              0.000   MEDIUM         1         1
# 12 0 days 00:58:51.178000              0.000   MEDIUM         1         1
# 13 0 days 00:58:51.660000              0.000     HARD         1         1
# 14 0 days 00:58:52.022000              0.000   MEDIUM         1         1
# 15 0 days 00:58:52.570000              0.000     SOFT         1         1
# 16 0 days 00:58:53.232000              0.000   MEDIUM         1         1
# 17 0 days 00:58:53.860000              0.000     HARD         1         1
# 18 0 days 00:58:54.612000              0.000     HARD         1         1
# 19 0 days 00:58:55.073000              0.000     HARD         1         1
# 20 0 days 00:58:41.675000             98.480   MEDIUM         2         1
# 21 0 days 00:58:42.664000             98.790   MEDIUM         2         1
# 22 0 days 00:58:43.953000             98.853     SOFT         2         1
# 23 0 days 00:58:45.073000             98.489   MEDIUM         2         1
# 24 0 days 00:58:46.519000             98.939   MEDIUM         2         1
# 25 0 days 00:58:46.974000             99.449   MEDIUM         2         1
# 26 0 days 00:58:47.635000             99.584   MEDIUM         2         1
# 27 0 days 00:58:48.341000             99.775   MEDIUM         2         1
# 28 0 days 00:58:48.947000             99.890   MEDIUM         2         1
# 29 0 days 00:58:49.401000             99.896   MEDIUM         2         1
# 30 0 days 00:58:50.150000             99.994   MEDIUM         2         1
# 31 0 days 00:58:50.752000            100.217   MEDIUM         2         1
# 32 0 days 00:58:51.178000            100.405   MEDIUM         2         1
# 33 0 days 00:58:51.660000            100.386     HARD         2         1
# 34 0 days 00:58:52.022000            100.750   MEDIUM         2         1
# 35 0 days 00:58:52.570000            100.947     SOFT         2         1
# 36 0 days 00:58:53.232000            100.948   MEDIUM         2         1
# 37 0 days 00:58:53.860000            101.184     HARD         2         1
# 38 0 days 00:58:54.612000            101.165     HARD         2         1
# 39 0 days 00:58:55.073000            101.595     HARD         2         1
# 40 0 days 00:58:41.675000            196.886   MEDIUM         3         1
# 41 0 days 00:58:42.664000            197.707   MEDIUM         3         1
# 42 0 days 00:58:43.953000            198.107     SOFT         3         1
# 43 0 days 00:58:45.073000            198.201   MEDIUM         3         1
# 44 0 days 00:58:46.519000            198.289   MEDIUM         3         1
# 45 0 days 00:58:46.974000            198.671   MEDIUM         3         1
# 46 0 days 00:58:47.635000            198.870   MEDIUM         3         1
# 47 0 days 00:58:48.341000            198.915   MEDIUM         3         1
# 48 0 days 00:58:48.947000            199.261   MEDIUM         3         1
# 49 0 days 00:58:49.401000            199.525   MEDIUM         3         1
#
#     LapTime  Position
# 0   100.424       1.0
# 1   101.413       2.0
# 2   102.702       3.0
# 3   103.822       4.0
# 4   105.268       5.0
# 5   105.723       6.0
# 6   106.384       7.0
# 7   107.090       8.0
# 8   107.696       9.0
# 9   108.150      10.0
# 10  108.899      11.0
# 11  109.501      12.0
# 12  109.927      13.0
# 13  110.409      14.0
# 14  110.771      15.0
# 15  111.319      16.0
# 16  111.981      17.0
# 17  112.609      18.0
# 18  113.361      19.0
# 19  113.822      20.0
# 20   98.480       1.0
# 21   98.790       2.0
# 22   98.853       3.0
# 23   98.489       4.0
# 24   98.939       5.0
# 25   99.449       6.0
# 26   99.584       7.0
# 27   99.775       8.0
# 28   99.890       9.0
# 29   99.896      10.0
# 30   99.994      11.0
# 31  100.217      12.0
# 32  100.405      13.0
# 33  100.386      14.0
# 34  100.750      15.0
# 35  100.947      16.0
# 36  100.948      17.0
# 37  101.184      18.0
# 38  101.165      19.0
# 39  101.595      20.0
# 40   98.406       1.0
# 41   98.917       2.0
# 42   99.254       3.0
# 43   99.712       4.0
# 44   99.350       5.0
# 45   99.222       6.0
# 46   99.286       7.0
# 47   99.140       8.0
# 48   99.371       9.0
# 49   99.629      10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77799 entries, 0 to 77798
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Driver             77799 non-null  object
#  1   Team               77799 non-null  object
#  2   LapNumber          77799 non-null  float64
#  3   LapTime            77799 non-null  float64
#  4   Compound           77799 non-null  object
#  5   TrackStatus        77799 non-null  int64
#  6   Position           77799 non-null  float64
#  7   Time               77799 non-null  timedelta64[ns]
#  8   AirTemp            77799 non-null  float64
#  9   Humidity           77799 non-null  float64
#  10  Pressure           77799 non-null  float64
#  11  Rainfall           77799 non-null  bool
#  12  TrackTemp          77799 non-null  float64
#  13  WindSpeed          77799 non-null  float64
#  14  WindDirection      77799 non-null  int64
#  15  Year               77799 non-null  int64
#  16  IsPitLap           77799 non-null  bool
#  17  NumPitStops        77799 non-null  int64
#  18  RaceID             77799 non-null  object
#  19  TireChange         77799 non-null  bool
#  20  StintStartTime     77799 non-null  timedelta64[ns]
#  21  TimeOnTireSeconds  77799 non-null  float64
#  22  StintNum           77799 non-null  int64
#  23  LapStint           77799 non-null  int64
# dtypes: bool(3), float64(9), int64(6), object(4), timedelta64[ns](2)
# memory usage: 12.7+ MB

# %%
df.groupby(['RaceID', 'Driver'])['LapTime'].apply(lambda x : (x > 200).sum()).sort_values(ascending=False).head(50)
# Out:
# RaceID                         Driver
# 2024_Monaco_Grand_Prix         SAI       1
#                                RIC       1
#                                BOT       1
#                                GAS       1
#                                HAM       1
#                                LEC       1
#                                NOR       1
#                                PIA       1
#                                RUS       1
# 2022_Monaco_Grand_Prix         LAT       1
# 2024_Monaco_Grand_Prix         SAR       1
#                                STR       1
#                                TSU       1
# 2022_Monaco_Grand_Prix         STR       1
# 2024_Monaco_Grand_Prix         VER       1
#                                ZHO       1
#                                ALO       1
#                                ALB       1
# 2022_British_Grand_Prix        OCO       1
#                                TSU       1
# 2022_Pre-Season_Track_Session  TSU       1
#                                OCO       1
# 2024_Australian_Grand_Prix     PIA       0
#                                RIC       0
# 2024_Abu_Dhabi_Grand_Prix      ZHO       0
# 2024_Australian_Grand_Prix     ALB       0
#                                ALO       0
#                                BOT       0
#                                PER       0
#                                SAI       0
#                                GAS       0
#                                HAM       0
#                                HUL       0
#                                LEC       0
#                                MAG       0
#                                NOR       0
#                                OCO       0
#                                RUS       0
# 2022_Abu_Dhabi_Grand_Prix      ALB       0
# 2024_Australian_Grand_Prix     STR       0
# 2024_Austrian_Grand_Prix       HUL       0
#                                RIC       0
#                                PIA       0
#                                PER       0
#                                OCO       0
#                                NOR       0
#                                MAG       0
#                                LEC       0
#                                HAM       0
# 2024_Australian_Grand_Prix     TSU       0
# Name: LapTime, dtype: int64

# %% [raw]
# Splitting and Training Data

# %%
target = 'LapTime'
features = [
    'Driver', 'Team', 'Compound', 'TrackStatus', 'Position',
    'AirTemp', 'Humidity', 'WindSpeed', 'WindDirection',
    'IsPitLap', 'NumPitStops',
    'StintNum', 'LapStint', 'TimeOnTireSeconds'
]

# %%
categorical_cols = ['Driver', 'Team', 'Compound', 'RaceID']

# %%
df_label = df.copy()
for col in categorical_cols:
    le = LabelEncoder()  # create a new instance each time
    df_label[col] = le.fit_transform(df_label[col].astype(str))

# %%
X = df[features]
y = df[target]
gkf = GroupKFold(n_splits=5)

model = RandomForestRegressor(n_estimators=100, random_state=42)

cv_results = cross_validate(
    model, X, y,
    cv=gkf.split(X, y, groups=df_label['RaceID']),
    scoring=['r2', 'neg_mean_absolute_error', 'neg_root_mean_squared_error'],
    return_train_score=True
)
print("Avg R²:", cv_results['test_r2'].mean())
print("Avg MAE:", -cv_results['test_neg_mean_absolute_error'].mean())
print("Avg RMSE:", -cv_results['test_neg_root_mean_squared_error'].mean())
# Out:
# Avg R²: -0.41763935532077123
# Avg MAE: 11.626696290616389
# Avg RMSE: 27.72941043324547
